# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  passwd="hitesh"
)

print(mydb)

# %%
mycursor = mydb.cursor()

mycursor.execute("CREATE DATABASE majorProject")
# Out:
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-2-ec7ce5f3c533> in <module>
#       1 mycursor = mydb.cursor()
#       2
# ----> 3 mycursor.execute("CREATE DATABASE majorProject")
#
# G:\Anaconda3\envs\py\lib\site-packages\mysql\connector\cursor.py in execute(self, operation, params, multi)
#     567
#     568         try:
# --> 569             self._handle_result(self._connection.cmd_query(stmt))
#     570         except errors.InterfaceError:
#     571             if self._connection._have_next_result:  # pylint: disable=W0212
#
# G:\Anaconda3\envs\py\lib\site-packages\mysql\connector\connection.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     588         if not isinstance(query, bytes):
#     589             query = query.encode('utf-8')
# --> 590         result = self._handle_result(self._send_cmd(ServerCmd.QUERY, query))
#     591
# ...

# %%
mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  passwd="hitesh",
  database="majorProject"
)

# %%
print(mydb)

# %%
mycursor = mydb.cursor()
mycursor.execute("DROP TABLE TV")

# %%
mycursor = mydb.cursor()

# %%
mycursor = mydb.cursor()

mycursor.execute("CREATE TABLE TV (Brand VARCHAR(15), Ratings DECIMAL(5,2), Speaker INT(1), Size INT(1), HD VARCHAR(15), HDMI INT(1), USB INT(1), Cost INT(6))")

# %%
import pandas as pd
data = pd.read_csv(r'G:\Major Project\TV_PricePrediction\Final_data.csv')

# %%
data.head()
# Out:
#      Brand  Ratings  Speaker  Size           HD  HDMI  USB   Cost
# 0       mi      4.4       20    32           HD     3    2  14999
# 1       mi      4.4       20    43  Ultra HD 4K     3    2  28999
# 2  samsung      4.4       20    32           HD     2    1  17499
# 3       lg      4.3       10    32           HD     2    1  16999
# 4  samsung      4.4       20    32           HD     2    1  16999

# %%
# creating column list for insertion
cols = "`,`".join([str(i) for i in data.columns.tolist()])
cols
# Out:
# 'Brand`,`Ratings`,`Speaker`,`Size`,`HD`,`HDMI`,`USB`,`Cost'

# %%
# Insert DataFrame recrds one by one.
for i,row in data.iterrows():
    sql = "INSERT INTO `TV` (`" +cols + "`) VALUES (" + "%s,"*(len(row)-1) + "%s)"
    mycursor.execute(sql, tuple(row))

    # the connection is not autocommitted by default, so we must commit to save our changes
    mydb.commit()

# %%
sql = "SELECT * FROM TV"
mycursor.execute(sql)

# %%
myresult = mycursor.fetchall()

for x in myresult:
  print(x)
# Out:
# ('mi', Decimal('4.40'), 20, 32, 'HD', 3, 2, 14999)
# ('mi', Decimal('4.40'), 20, 43, 'Ultra HD 4K', 3, 2, 28999)
# ('samsung', Decimal('4.40'), 20, 32, 'HD', 2, 1, 17499)
# ('lg', Decimal('4.30'), 10, 32, 'HD', 2, 1, 16999)
# ('samsung', Decimal('4.40'), 20, 32, 'HD', 2, 1, 16999)
# ('mi', Decimal('4.40'), 20, 40, 'Full HD', 3, 2, 22999)
# ('mi', Decimal('4.40'), 20, 50, 'Ultra HD 4K', 3, 2, 34999)
# ('iffalcon', Decimal('4.30'), 24, 50, 'Ultra HD 4K', 3, 1, 28999)
# ('mi', Decimal('4.40'), 20, 32, 'HD', 3, 2, 15999)
# ('mi', Decimal('4.40'), 20, 43, 'Full HD', 3, 3, 24999)
# ('lg', Decimal('4.40'), 20, 43, 'Ultra HD 4K', 3, 2, 35999)
# ('samsung', Decimal('4.40'), 20, 65, 'Ultra HD 4K', 4, 2, 99999)
# ('vu', Decimal('4.50'), 30, 50, 'Ultra HD 4K', 3, 2, 36999)
# ('mi', Decimal('4.40'), 20, 32, 'HD', 3, 2, 15999)
# ('mi', Decimal('4.40'), 20, 43, 'Ultra HD 4K', 3, 2, 27999)
# ('iffalcon', Decimal('4.30'), 24, 55, 'Ultra HD 4K', 3, 1, 34999)
# ...

# %%
rating=4.50
speaker=20
size=43
hd='Full HD'
hdmi=3
usb=2

# %%
hd
# Out:
# 'Full HD'

# %%
query = "Select * from TV where `HD`='Full HD'"

AND `HD`={} AND `HDMI`={} AND`USB`={}"
,hd,hdmi,usb

# %%
query = "Select * from TV where `Speaker`=%s AND `Size`=%s AND `HD`=%s AND `HDMI`=%s AND `USB`=%s ORDER BY `Cost`, `Ratings`"
inputs=(speaker,size,hd,hdmi,usb)

# %%
mycursor.execute(query,inputs)

# %%
myresult = mycursor.fetchall()

for x in myresult:
  print(x)
# Out:
# ('haier', Decimal('4.30'), 20, 43, 'Full HD', 3, 2, 28890)
# ('panasonic', Decimal('4.30'), 20, 43, 'Full HD', 3, 2, 30999)
# ('lg', Decimal('4.20'), 20, 43, 'Full HD', 3, 2, 34999)

# %%
type(myresult)
# Out:
# list

# %%
dataframe=pd.DataFrame(myresult)

# %%
l=dataframe.iloc[0,:].values

# %%
l
# Out:
# array(['haier', Decimal('4.30'), 20, 43, 'Full HD', 3, 2, 28890],
#       dtype=object)
